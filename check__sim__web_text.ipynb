# %%
import pandas as pd
# import sys
# sys.path.append("D:\PUBLIC_DATA_PROJECT\Domain_cluster")

from tools.crawl import WebScraper 
from tools.preprocessing import preprocessing

# %% [markdown]
# # DATA

# %%
df = pd.read_csv("D:\PUBLIC_DATA_PROJECT\Check_main_url\company_1.csv")
df1 = pd.read_csv("D:\PUBLIC_DATA_PROJECT\Check_main_url\info_company1.csv")
df = pd.concat([df, df1], axis=0).reset_index(drop=True)
df["code"] = df["code"].astype(str)
df.head()
# Out:
#                                         link_company  \
# 0  https://hosocongty.vn/tap-doan-vingroup-cong-t...
# 1  https://hosocongty.vn/tong-cong-ty-bao-hiem-ba...
# 2  https://hosocongty.vn/cong-ty-co-phan-bibica-c...
# 3  https://hosocongty.vn/cong-ty-co-phan-bao-hiem...
# 4  https://hosocongty.vn/cong-ty-co-phan-nhua-va-...
#
#                                       name_company          code  \
# 0                  TẬP ĐOÀN VINGROUP -  CÔNG TY CP   101245486.0
# 1                   TỔNG CÔNG TY BẢO HIỂM BẢO VIỆT   101527385.0
# 2                           CÔNG TY CỔ PHẦN BIBICA  3600363970.0
# 3              CÔNG TY CỔ PHẦN BẢO HIỂM HÀNG KHÔNG   102737963.0
# 4  CÔNG TY CỔ PHẦN NHỰA VÀ MÔI TRƯỜNG XANH AN PHÁT   800789746.0
#
#                       status_of_company  \
# 0  Đang hoạt động (đã được cấp GCN ĐKT)
# 1                                   NaN
# 2  Đang hoạt động (đã được cấp GCN ĐKT)
# 3                                   NaN
# 4                                   NaN
#
#                                        list_business  \
# 0  [{'5510': 'Dịch vụ lưu trú ngắn ngày'}, {'4772...
# 1          [{'65129': 'Bảo hiểm phi nhân thọ khác'}]
# 2  [{'1071': 'Sản xuất các loại bánh từ bột'}, {'...
# 3  [{'64': 'Hoạt động dịch vụ tài chính (trừ bảo ...
# 4  [{'963': 'Hoạt động dịch vụ phục vụ cá nhân kh...
#
#                                         list_website  Status  \
# 0  [{'title': 'Trang chủ - Tập đoàn Vingroup', 'u...    True
# 1  [{'title': 'Tổng Công ty Bảo hiểm Bảo Việt', '...    True
# 2  [{'title': 'Bibica - Tinh hoa bánh kẹo Việt', ...    True
# 3  [{'title': 'VNI - Tổng Công Ty Cổ Phần Bảo hiể...    True
# 4  [{'title': 'An Phat Bioplastics', 'url': 'http...    True
#
#   international_name  acronyms_name address representative phone_number  \
# 0                NaN            NaN     NaN            NaN          NaN
# 1                NaN            NaN     NaN            NaN          NaN
# 2                NaN            NaN     NaN            NaN          NaN
# 3                NaN            NaN     NaN            NaN          NaN
# 4                NaN            NaN     NaN            NaN          NaN
#
#   day_of_operation main_job update_time  id
# 0              NaN      NaN         NaN NaN
# 1              NaN      NaN         NaN NaN
# 2              NaN      NaN         NaN NaN
# 3              NaN      NaN         NaN NaN
# 4              NaN      NaN         NaN NaN

# %%
'''Input requirements
    Schema: 'link_company', 'name_company', 'code', 'status_of_company',
       'list_business', 'list_website', 'Status', 'international_name',
       'acronyms_name', 'address', 'representative', 'phone_number',
       'day_of_operation', 'main_job', 'update_time', 'id'
''' 

df = preprocessing(df)

# %%
df.head()
# Out:
#                                         link_company  \
# 0  https://hosocongty.vn/tap-doan-vingroup-cong-t...
# 1  https://hosocongty.vn/tong-cong-ty-bao-hiem-ba...
# 2  https://hosocongty.vn/cong-ty-co-phan-bibica-c...
# 3  https://hosocongty.vn/cong-ty-co-phan-bao-hiem...
# 4  https://hosocongty.vn/cong-ty-co-phan-nhua-va-...
#
#                                       name_company          code  \
# 0                  TẬP ĐOÀN VINGROUP -  CÔNG TY CP   101245486.0
# 1                   TỔNG CÔNG TY BẢO HIỂM BẢO VIỆT   101527385.0
# 2                           CÔNG TY CỔ PHẦN BIBICA  3600363970.0
# 3              CÔNG TY CỔ PHẦN BẢO HIỂM HÀNG KHÔNG   102737963.0
# 4  CÔNG TY CỔ PHẦN NHỰA VÀ MÔI TRƯỜNG XANH AN PHÁT   800789746.0
#
#                       status_of_company  \
# 0  Đang hoạt động (đã được cấp GCN ĐKT)
# 1                                   NaN
# 2  Đang hoạt động (đã được cấp GCN ĐKT)
# 3                                   NaN
# 4                                   NaN
#
#                                        list_business  \
# 0  [{'5510': 'Dịch vụ lưu trú ngắn ngày'}, {'4772...
# 1          [{'65129': 'Bảo hiểm phi nhân thọ khác'}]
# 2  [{'1071': 'Sản xuất các loại bánh từ bột'}, {'...
# 3  [{'64': 'Hoạt động dịch vụ tài chính (trừ bảo ...
# 4  [{'963': 'Hoạt động dịch vụ phục vụ cá nhân kh...
#
#                                         list_website  Status  \
# 0  [{'title': 'Trang chủ - Tập đoàn Vingroup', 'u...    True
# 1  [{'title': 'Tổng Công ty Bảo hiểm Bảo Việt', '...    True
# 2  [{'title': 'Bibica - Tinh hoa bánh kẹo Việt', ...    True
# 3  [{'title': 'VNI - Tổng Công Ty Cổ Phần Bảo hiể...    True
# 4  [{'title': 'An Phat Bioplastics', 'url': 'http...    True
#
#   international_name  acronyms_name address representative phone_number  \
# 0                NaN            NaN     NaN            NaN          NaN
# 1                NaN            NaN     NaN            NaN          NaN
# 2                NaN            NaN     NaN            NaN          NaN
# 3                NaN            NaN     NaN            NaN          NaN
# 4                NaN            NaN     NaN            NaN          NaN
#
#   day_of_operation main_job update_time  id  \
# 0              NaN      NaN         NaN NaN
# 1              NaN      NaN         NaN NaN
# 2              NaN      NaN         NaN NaN
# 3              NaN      NaN         NaN NaN
# 4              NaN      NaN         NaN NaN
#
#                                       extracted_urls
# 0  [https://vingroup.net/, https://mekongasean.vn...
# 1  [https://www.baoviet.com.vn/insurance/, https:...
# 2  [https://www.bibica.com.vn/, https://s.cafef.v...
# 3  [https://bhhk.com.vn/, https://ebhhk.com.vn/gi...
# 4  [https://anphatbioplastics.com/, https://finan...

# %%
import ast
# Hàm để in URL từ cột list_business
def print_urls_from_business(row):
    print(f"Company: {row['name_company']}")
    print(f"Tax Code: {row['code']}")
    # Chuyển đổi chuỗi JSON-like thành list thực, sau khi qua code Tan thi khong can na
    # business_list = ast.literal_eval(row['list_website'])

    business_list = row['extracted_urls']

    # Duyệt qua từng URL và in ra
    for business in business_list:
        print(f"URL: {business}")
    print("="*50)

    # # Duyệt qua từng URL và in ra
    # for business in business_list:
    #     print(f"URL: {business['url']}")
    # print("="*50)

# # Áp dụng hàm cho từng hàng của DataFrame
# df.apply(print_urls_from_business, axis=1)

# %%
for i in range(len(df)):
    row = df.iloc[i, :]
    print_urls_from_business(row)
# Out:
# Company: TẬP ĐOÀN VINGROUP -  CÔNG TY CP
# Tax Code: 101245486.0
# URL: https://vingroup.net/
# URL: https://mekongasean.vn/to-ng-ta-i-sa-n-vingroup-vuot-nguong-700000-ty-do-ng-31407.html#:~:text=T%E1%BB%95ng%20s%E1%BB%91%20n%E1%BB%A3%20c%E1%BB%A7a%20Vingroup,l%E1%BB%9Bn%20v%E1%BB%9Bi%20418.112%20t%E1%BB%B7%20%C4%91%E1%BB%93ng.
# ==================================================
# Company: TỔNG CÔNG TY BẢO HIỂM BẢO VIỆT
# Tax Code: 101527385.0
# URL: https://www.baoviet.com.vn/insurance/
# URL: https://baovietonline.com.vn/
# URL: https://baoviet.com.vn/
# ==================================================
# Company: CÔNG TY CỔ PHẦN BIBICA
# Tax Code: 3600363970.0
# URL: https://www.bibica.com.vn/
# URL: https://s.cafef.vn/hose/BBC-cong-ty-co-phan-bibica.chn
# URL: https://finance.vietstock.vn/bbc/ho-so-doanh-nghiep.htm
# ==================================================
# Company: CÔNG TY CỔ PHẦN BẢO HIỂM HÀNG KHÔNG
# Tax Code: 102737963.0
# URL: https://bhhk.com.vn/
# URL: https://ebhhk.com.vn/gioi-thieu.html
# URL: https://ibaohiem.vn/gioi-thieu-bao-hiem-hang-khong-vni/
# ==================================================
# Company: CÔNG TY CỔ PHẦN NHỰA VÀ MÔI TRƯỜNG XANH AN PHÁT
# Tax Code: 800789746.0
# URL: https://anphatbioplastics.com/
# URL: https://finance.vietstock.vn/AAA-ctcp-nhua-an-phat-xanh.htm
# URL: https://www.fact-link.com.vn/home/anphat-vn
# ==================================================
# Company: CÔNG TY TNHH P&P HEALING HOUSE
# Tax Code: 315717961.0
# URL: http://p-techno.com/
# URL: https://www.dussmann.vn/vi/dussmann-service/cong-ty/
# ==================================================
# Company: CÔNG TY TNHH XUẤT NHẬP KHẨU KORE
# Tax Code: 315717954.0
# URL: https://oneoneone.vn/organic-farms-korea/
# ==================================================
# Company: CÔNG TY TNHH DỊCH VỤ BẤT ĐỘNG SẢN H & N
# Tax Code: 315717922.0
# URL: https://www.pghouse.vn/doanh-nghiep-vang/cong-ty-tnhh-dich-vu-bat-dong-san-premier-viet-nam-10875.html
# ==================================================
# Company: CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ C.Z.C
# Tax Code: 315717915.0
# URL: https://www.taiphat.vn/
# URL: https://minhkhang.com.vn/
# URL: https://vietincoseco.vn/
# ==================================================
# Company: CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ VẬN TẢI SONG NHẬT
# Tax Code: 315717898.0
# URL: https://songnhat.com.vn/
# ==================================================
# Company: CÔNG TY TNHH HẠT NHỰA HỮU NGHỊ
# Tax Code: 315714720.0
# URL: https://huunghiplastic.com.vn/
# ==================================================
# Company: CÔNG TY TNHH THƯƠNG MẠI HONG PU TRUNG QUỐC
# Tax Code: 315716100.0
# ==================================================
# Company: CÔNG TY TNHH GLOBAL STONE IMP&EXP
# Tax Code: 315716037.0
# ==================================================
# Company: CÔNG TY TNHH EMA TECH
# Tax Code: 315707931.0
# URL: https://ematechvn.com/
# ==================================================
# Company: CÔNG TY TNHH SẢN XUẤT THƯƠNG MẠI DỊCH VỤ HÙNG UY VƯƠNG
# Tax Code: 315703013.0
# URL: https://baocaothongtin.com/vi/congty/vn-VN0001430704/hung-uy-vuong-production-trading-service-company-limited/
# ==================================================
# Company: CÔNG TY TNHH KINH DOANH THƯƠNG MẠI DỊCH VỤ HOÀNG HƯNG PHÁT
# Tax Code: 315715971.0
# ==================================================
# Company: CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ HỌA BÌ
# Tax Code: 315714921.0
# URL: https://infodoanhnghiep.com/thong-tin/Cty-TNHH-MTV-Thuong-Mai-Dich-Vu-Hoa-Bi-49927.html
# ==================================================
# Company: CÔNG TY TNHH ĐẠI YẾN VIỆT
# Tax Code: 315715731.0
# URL: https://www.yenviet.com.vn/
# ==================================================
# Company: CÔNG TY TNHH ZHONGHENG PRINTING
# Tax Code: 315714752.0
# ==================================================
# Company: CÔNG TY TNHH ĐẦU TƯ VÀ PHÁT TRIỂN EURO LAND VIỆT NAM
# Tax Code: 315713572.0
# URL: http://euroland.dichvuvietbaichuanseo.com/
# ==================================================
# Company: CÔNG TY TNHH BẤT ĐỘNG SẢN HOÀNG THIÊN PHÁT
# Tax Code: 315712360.0
# ==================================================

# %%
Worker = WebScraper(saving_path="D:/PUBLIC_DATA_PROJECT/Check_main_url/crawl",
                    get_subdomain=False)
#process_url(self, url, id, count):


import ast
# Hàm để crawl URL từ cột list_business
def task(row):
    print(f"Company: {row['name_company']}")
    print(f"Tax Code: {row['code']}")
    tax = row['code'].split(".")[0]

    business_list = row['extracted_urls']

    # Duyệt qua từng URL và in ra
    for index, business in enumerate(business_list):
        # url = business['url']
        url = business
        try:
            Worker.process_url(url, tax, index)
        except:
            continue

    print("="*50)


for i in range(len(df)):
    row = df.iloc[i, :]
    task(row)
# Out:
# Company: TẬP ĐOÀN VINGROUP -  CÔNG TY CP
# Tax Code: 101245486.0
# url:  https://vingroup.net/
# url: https://vingroup.net/
#  Saved: D:/PUBLIC_DATA_PROJECT/Check_main_url/crawl/company_information/101245486/0.txt
# url:  https://mekongasean.vn/to-ng-ta-i-sa-n-vingroup-vuot-nguong-700000-ty-do-ng-31407.html#:~:text=T%E1%BB%95ng%20s%E1%BB%91%20n%E1%BB%A3%20c%E1%BB%A7a%20Vingroup,l%E1%BB%9Bn%20v%E1%BB%9Bi%20418.112%20t%E1%BB%B7%20%C4%91%E1%BB%93ng.
#  Saved: D:/PUBLIC_DATA_PROJECT/Check_main_url/crawl/company_information/315711381/0.txt
# ==================================================
# Company: CÔNG TY CỔ PHẦN GIẢI PHÁP CHIẾU SÁNG VÀ NĂNG LƯỢNG SOHOBI
# Tax Code: 315715587.0
# url:  https://denledchatluongcao.vn/
# url: https://denledchatluongcao.vn/
#  Saved: D:/PUBLIC_DATA_PROJECT/Check_main_url/crawl/company_information/315715587/0.txt
# ==================================================
# Company: CÔNG TY TNHH SENTMEN
# Tax Code: 315715717.0
# ==================================================
# Company: CÔNG TY TNHH MT TIẾN QUÂN
# Tax Code: 315715442.0
# url:  https://automation-tienquan.com/
# url: https://automation-tienquan.com/
#  Saved: D:/PUBLIC_DATA_PROJECT/Check_main_url/crawl/company_information/315715442/0.txt
# ==================================================
# Company: CÔNG TY TNHH ĐẠI HOÀ JA
# Tax Code: 315714745.0
# url:  https://daihoabinhduong.com/
# url: https://daihoabinhduong.com/
#  Saved: D:/PUBLIC_DATA_PROJECT/Check_main_url/crawl/company_information/315714745/0.txt
# url:  https://daihoaco.com/
# url: https://daihoaco.com/
#  Saved: D:/PUBLIC_DATA_PROJECT/Check_main_url/crawl/company_information/315714745/1.txt
# ==================================================
# Company: CÔNG TY TNHH NỮ HOÀNG MÙA XUÂN
# Tax Code: 315714590.0
# url:  https://nuhoanghodiep.com/
# url:  https://globalfoodsource.vn/
# url: https://globalfoodsource.vn/
#  Saved: D:/PUBLIC_DATA_PROJECT/Check_main_url/crawl/company_information/315714590/1.txt
# ==================================================
# Company: CÔNG TY TNHH TOP QUALITY FOR HOME
# Tax Code: 315709505.0
# ==================================================
# Company: CÔNG TY TNHH HẠT NHỰA HỮU NGHỊ
# Tax Code: 315714720.0
# url:  https://huunghiplastic.com.vn/
# url: https://huunghiplastic.com.vn/
#  Saved: D:/PUBLIC_DATA_PROJECT/Check_main_url/crawl/company_information/315714720/0.txt
# ==================================================
# Company: CÔNG TY TNHH THƯƠNG MẠI HONG PU TRUNG QUỐC
# Tax Code: 315716100.0
# ==================================================
# Company: CÔNG TY TNHH GLOBAL STONE IMP&EXP
# Tax Code: 315716037.0
# ==================================================
# Company: CÔNG TY TNHH EMA TECH
# Tax Code: 315707931.0
# url:  https://ematechvn.com/
# url: https://ematechvn.com/
#  Saved: D:/PUBLIC_DATA_PROJECT/Check_main_url/crawl/company_information/315707931/0.txt
# ==================================================
# Company: CÔNG TY TNHH SẢN XUẤT THƯƠNG MẠI DỊCH VỤ HÙNG UY VƯƠNG
# Tax Code: 315703013.0
# url:  https://baocaothongtin.com/vi/congty/vn-VN0001430704/hung-uy-vuong-production-trading-service-company-limited/
# url: https://baocaothongtin.com/vi/congty/vn-VN0001430704/hung-uy-vuong-production-trading-service-company-limited/
#  Saved: D:/PUBLIC_DATA_PROJECT/Check_main_url/crawl/company_information/315703013/0.txt
# ==================================================
# Company: CÔNG TY TNHH KINH DOANH THƯƠNG MẠI DỊCH VỤ HOÀNG HƯNG PHÁT
# Tax Code: 315715971.0
# ==================================================
# Company: CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ HỌA BÌ
# Tax Code: 315714921.0
# url:  https://infodoanhnghiep.com/thong-tin/Cty-TNHH-MTV-Thuong-Mai-Dich-Vu-Hoa-Bi-49927.html
# url: https://infodoanhnghiep.com/thong-tin/Cty-TNHH-MTV-Thuong-Mai-Dich-Vu-Hoa-Bi-49927.html
#  Saved: D:/PUBLIC_DATA_PROJECT/Check_main_url/crawl/company_information/315714921/0.txt
# ==================================================
# Company: CÔNG TY TNHH ĐẠI YẾN VIỆT
# Tax Code: 315715731.0
# url:  https://www.yenviet.com.vn/
# url: https://www.yenviet.com.vn/
#  Saved: D:/PUBLIC_DATA_PROJECT/Check_main_url/crawl/company_information/315715731/0.txt
# ==================================================
# Company: CÔNG TY TNHH ZHONGHENG PRINTING
# Tax Code: 315714752.0
# ==================================================
# Company: CÔNG TY TNHH ĐẦU TƯ VÀ PHÁT TRIỂN EURO LAND VIỆT NAM
# Tax Code: 315713572.0
# url:  http://euroland.dichvuvietbaichuanseo.com/
# url: http://euroland.dichvuvietbaichuanseo.com/
#  Saved: D:/PUBLIC_DATA_PROJECT/Check_main_url/crawl/company_information/315713572/0.txt
# ==================================================
# Company: CÔNG TY TNHH BẤT ĐỘNG SẢN HOÀNG THIÊN PHÁT
# Tax Code: 315712360.0
# ==================================================

# %%
business_meta = {}
import os
import ast
# Hàm để in URL từ cột list_business
def task(row, business):
    print(f"Company: {row['name_company']}")
    print(f"Tax Code: {row['code']}")
    tax = row['code'].split(".")[0]
    # Chuyển đổi chuỗi JSON-like thành list thực
    # business_list = ast.literal_eval(row['list_website'])
    business_list = row['extracted_urls']
    # Duyệt qua từng URL và in ra

    urls = []
    paths = []
    for index, business in enumerate(business_list):
        # url = business['url']
        url = business
        path = f"D:\PUBLIC_DATA_PROJECT\Check_main_url\crawl\company_information\{tax}\{index}.txt"

        if os.path.exists(path):
            urls.append(url)
            paths.append(path)

            industry_list = ["".join(x.values()) for x in ast.literal_eval(row["list_business"])]
            industry_list = ",".join(industry_list)


    if len(paths) > 0:
        business_meta[tax] = {
            'urls': urls,
            'paths': paths,
            'name': row['name_company'],
            'industry_text': industry_list
        }
        print(business)

    print("="*50)


for i in range(len(df)):
    row = df.iloc[i, :]
    task(row, business_meta)
# Out:
# Company: TẬP ĐOÀN VINGROUP -  CÔNG TY CP
# Tax Code: 101245486.0
# https://mekongasean.vn/to-ng-ta-i-sa-n-vingroup-vuot-nguong-700000-ty-do-ng-31407.html#:~:text=T%E1%BB%95ng%20s%E1%BB%91%20n%E1%BB%A3%20c%E1%BB%A7a%20Vingroup,l%E1%BB%9Bn%20v%E1%BB%9Bi%20418.112%20t%E1%BB%B7%20%C4%91%E1%BB%93ng.
# ==================================================
# Company: TỔNG CÔNG TY BẢO HIỂM BẢO VIỆT
# Tax Code: 101527385.0
# https://baoviet.com.vn/
# ==================================================
# Company: CÔNG TY CỔ PHẦN BIBICA
# Tax Code: 3600363970.0
# https://finance.vietstock.vn/bbc/ho-so-doanh-nghiep.htm
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\101245486\\0.txt',
#    'D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\101245486\\1.txt'],
#   'name': 'TẬP ĐOÀN VINGROUP -  CÔNG TY CP',
#   'industry_text': 'Dịch vụ lưu trú ngắn ngày,Bán lẻ thuốc, dụng cụ y tế, mỹ phẩm và vật phẩm vệ sinh trong các cửa hàng chuyên doanh,Nhà hàng và các dịch vụ ăn uống phục vụ lưu động,Tư vấn máy vi tính và quản trị hệ thống máy vi tính,Hoạt động dịch vụ công nghệ thông tin và dịch vụ khác liên quan đến máy vi tính,Xử lý dữ liệu, cho thuê và các hoạt động liên quan,Khai thác, xử lý và cung cấp nước,Thoát nước và xử lý nước thải,Thu gom rác thải không độc hại,Phá dỡ,Chuẩn bị mặt bằng,Lắp đặt hệ thống điện,Lắp đặt hệ thống xây dựng khác,Hoàn thiện công trình xây dựng,Hoạt động xây dựng chuyên dụng khác,Bán buôn nông, lâm sản nguyên liệu (trừ gỗ, tre, nứa) và động vật sống,Bán buôn đồ dùng khác cho gia đình,Bán buôn máy móc, thiết bị và phụ tùng máy khác,Hoạt động sáng tác, nghệ thuật và giải trí,Hoạt động của các cơ sở thể thao,Hoạt động của các công viên vui chơi và công viên theo chủ đề,Hoạt động vui chơi giải trí khác chưa được phân vào đâu,Hoạt động hỗ trợ dịch vụ tài chính chưa được phân vào đâu,Kinh doanh bất động sản, quyền sử dụng đất thuộc chủ sở hữu, chủ sử dụng hoặc đi thuê,Tư vấn, môi giới, đấu giá bất động sản, đấu giá quyền sử dụng đất,Hoạt động của trụ sở văn phòng,Hoạt động tư vấn quản lý,Hoạt động kiến trúc và tư vấn kỹ thuật có liên quan,Quảng cáo,Nghiên cứu thị trường và thăm dò dư luận,Dịch vụ hành chính văn phòng tổng hợp,Lắp đặt hệ thống cấp, thoát nước, lò sưởi và điều hoà không khí,Đại lý, môi giới, đấu giá,Xây dựng nhà để ở,Xây dựng nhà không để ở,Xây dựng công trình đường sắt,Xây dựng công trình đường bộ,Xây dựng công trình công ích khác,Xây dựng công trình kỹ thuật dân dụng khác'},
#  '101527385': {'urls': ['https://www.baoviet.com.vn/insurance/',
#    'https://baovietonline.com.vn/',
#    'https://baoviet.com.vn/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\101527385\\0.txt',
#    'D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\101527385\\1.txt',
#    'D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\101527385\\2.txt'],
#   'name': 'TỔNG CÔNG TY BẢO HIỂM BẢO VIỆT',
#   'industry_text': 'Bảo hiểm phi nhân thọ khác'},
#  '3600363970': {'urls': ['https://www.bibica.com.vn/',
#    'https://s.cafef.vn/hose/BBC-cong-ty-co-phan-bibica.chn',
#    'https://finance.vietstock.vn/bbc/ho-so-doanh-nghiep.htm'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\3600363970\\0.txt',
#    'D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\3600363970\\1.txt',
#    'D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\3600363970\\2.txt'],
#   'name': 'CÔNG TY CỔ PHẦN BIBICA',
#   'industry_text': 'Sản xuất các loại bánh từ bột,Sản xuất giấy nhăn, bìa nhăn, bao bì từ giấy và bìa,Sản xuất ca cao, sôcôla và mứt kẹo,Sản xuất đồ uống không cồn, nước khoáng,Chưng, tinh cất và pha chế các loại rượu mạnh,Sản xuất thực phẩm khác chưa được phân vào đâu,Bán buôn thực phẩm,Bán buôn đồ uống,Kinh doanh bất động sản, quyền sử dụng đất thuộc chủ sở hữu, chủ sử dụng hoặc đi thuê,Chế biến và bảo quản rau quả,Quảng cáo,Đại lý, môi giới, đấu giá,Vận tải hàng hóa bằng đường bộ,Hoạt động dịch vụ hỗ trợ khác liên quan đến vận tải,Kho bãi và lưu giữ hàng hóa,Bốc xếp hàng hóa,Dịch vụ đóng gói,Sản xuất sản phẩm từ plastic,Sản xuất sản phẩm khác bằng kim loại chưa được phân vào đâu,Chế biến, bảo quản thịt và các sản phẩm từ thịt,Chế biến, bảo quản thuỷ sản và các sản phẩm từ thuỷ sản,Sản xuất đường'},
#  '102737963': {'urls': ['https://bhhk.com.vn/',
#    'https://ebhhk.com.vn/gioi-thieu.html',
#    'https://ibaohiem.vn/gioi-thieu-bao-hiem-hang-khong-vni/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\102737963\\0.txt',
#    'D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\102737963\\1.txt',
#    'D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\102737963\\2.txt'],
#   'name': 'CÔNG TY CỔ PHẦN BẢO HIỂM HÀNG KHÔNG',
#   'industry_text': 'Hoạt động dịch vụ tài chính (trừ bảo hiểm và bảo hiểm xã hội)'},
#  '800789746': {'urls': ['https://anphatbioplastics.com/',
#    'https://finance.vietstock.vn/AAA-ctcp-nhua-an-phat-xanh.htm',
#    'https://www.fact-link.com.vn/home/anphat-vn'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\800789746\\0.txt',
#    'D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\800789746\\1.txt',
#    'D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\800789746\\2.txt'],
#   'name': 'CÔNG TY CỔ PHẦN NHỰA VÀ MÔI TRƯỜNG XANH AN PHÁT',
#   'industry_text': 'Hoạt động dịch vụ phục vụ cá nhân khác chưa được phân vào đâu'},
#  '315717961': {'urls': ['http://p-techno.com/',
#    'https://www.dussmann.vn/vi/dussmann-service/cong-ty/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315717961\\0.txt',
#    'D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315717961\\1.txt'],
#   'name': 'CÔNG TY TNHH P&P HEALING HOUSE',
#   'industry_text': 'Bán buôn thực phẩm,Bán lẻ thực phẩm trong các cửa hàng chuyên doanh,Bán lẻ đồ uống trong các cửa hàng chuyên doanh,Đại lý, môi giới, đấu giá,Bán lẻ đồ điện gia dụng, giường, tủ, bàn, ghế và đồ nội thất tương tự, đèn và bộ đèn điện, đồ dùng gia đình khác chưa được phân vào đâu trong các cửa hàng chuyên doanh,Nhà hàng và các dịch vụ ăn uống phục vụ lưu động,Bán buôn máy móc, thiết bị và phụ tùng máy khác,Tổ chức giới thiệu và xúc tiến thương mại,Bán lẻ máy vi tính, thiết bị ngoại vi, phần mềm và thiết bị viễn thông trong các cửa hàng chuyên doanh,Bán lẻ thuốc, dụng cụ y tế, mỹ phẩm và vật phẩm vệ sinh trong các cửa hàng chuyên doanh,Bán buôn thiết bị và linh kiện điện tử, viễn thông,Bán lẻ hàng may mặc, giày dép, hàng da và giả da trong các cửa hàng chuyên doanh,Bán lẻ hàng hóa khác mới trong các cửa hàng chuyên doanh,Bán buôn vải, hàng may sẵn, giày dép,Bán buôn đồ uống,Bán buôn chuyên doanh khác chưa được phân vào đâu,Bán buôn đồ dùng khác cho gia đình,Cho thuê máy móc, thiết bị và đồ dùng hữu hình khác,Bán buôn máy vi tính, thiết bị ngoại vi và phần mềm'},
#  '315717954': {'urls': ['https://oneoneone.vn/organic-farms-korea/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315717954\\0.txt'],
#   'name': 'CÔNG TY TNHH XUẤT NHẬP KHẨU KORE',
#   'industry_text': 'Bán buôn chuyên doanh khác chưa được phân vào đâu,Bán lẻ hàng hóa khác mới trong các cửa hàng chuyên doanh'},
#  '315717922': {'urls': ['https://www.pghouse.vn/doanh-nghiep-vang/cong-ty-tnhh-dich-vu-bat-dong-san-premier-viet-nam-10875.html'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315717922\\0.txt'],
#   'name': 'CÔNG TY TNHH DỊCH VỤ BẤT ĐỘNG SẢN H & N',
#   'industry_text': 'Tư vấn, môi giới, đấu giá bất động sản, đấu giá quyền sử dụng đất,Đại lý, môi giới, đấu giá'},
#  '315717915': {'urls': ['https://www.taiphat.vn/',
#    'https://minhkhang.com.vn/',
#    'https://vietincoseco.vn/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315717915\\0.txt',
#    'D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315717915\\1.txt',
#    'D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315717915\\2.txt'],
#   'name': 'CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ C.Z.C',
#   'industry_text': 'Bán buôn kim loại và quặng kim loại,Bán buôn vật liệu, thiết bị lắp đặt khác trong xây dựng,Kho bãi và lưu giữ hàng hóa,Bán buôn chuyên doanh khác chưa được phân vào đâu,Hoạt động xây dựng chuyên dụng khác,Vận tải hàng hóa bằng đường bộ,Vận tải hàng hóa đường thuỷ nội địa'},
#  '315717898': {'urls': ['https://songnhat.com.vn/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315717898\\0.txt'],
#   'name': 'CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ VẬN TẢI SONG NHẬT',
#   'industry_text': 'Vận tải hàng hóa bằng đường bộ,Hoạt động dịch vụ hỗ trợ trực tiếp cho vận tải đường bộ,Hoạt động dịch vụ hỗ trợ khác liên quan đến vận tải,Kho bãi và lưu giữ hàng hóa,Cho thuê xe có động cơ,Bốc xếp hàng hóa'},
#  '315718891': {'urls': ['https://myphambeautyqueen.net/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315718891\\0.txt'],
#   'name': 'CÔNG TY TNHH MỸ PHẨM SPA BEAUTY QUEEN',
#   'industry_text': 'Hoạt động dịch vụ phục vụ cá nhân khác còn lại chưa được phân vào đâu,Bán buôn thực phẩm,Tư vấn, môi giới, đấu giá bất động sản, đấu giá quyền sử dụng đất,Bán lẻ thuốc, dụng cụ y tế, mỹ phẩm và vật phẩm vệ sinh trong các cửa hàng chuyên doanh,Dịch vụ tắm hơi, massage và các dịch vụ tăng cường sức khoẻ tương tự (trừ hoạt động thể thao),Bán buôn đồ dùng khác cho gia đình,Cắt tóc, làm đầu, gội đầu'},
#  '315717979': {'urls': ['https://mioskin.vn/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315717979\\0.txt'],
#   'name': 'CÔNG TY CỔ PHẦN MỸ PHẨM MIOSKIN',
#   'industry_text': 'Bán buôn đồ dùng khác cho gia đình,Bán lẻ thuốc, dụng cụ y tế, mỹ phẩm và vật phẩm vệ sinh trong các cửa hàng chuyên doanh,Quảng cáo,Tổ chức giới thiệu và xúc tiến thương mại,Hoạt động sáng tác, nghệ thuật và giải trí'},
#  '315715883': {'urls': ['https://giaan115.com/tin-tuc/khu-y-te-ky-thuat-cao-hoa-lam-shangri-la-da-ra-doi-nhu-the-nao'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315715883\\0.txt'],
#   'name': 'CÔNG TY TNHH DỊCH VỤ SHANGRI-LA',
#   'industry_text': 'Dịch vụ tắm hơi, massage và các dịch vụ tăng cường sức khoẻ tương tự (trừ hoạt động thể thao),Bán buôn đồ uống,Bán buôn đồ dùng khác cho gia đình,Cắt tóc, làm đầu, gội đầu'},
#  '315713741': {'urls': ['https://doanhnghiepmoi.vn/thong-tin/CONG-TY-TNHH-HANG-HAI-QUOC-TUAN-13741.html',
#    'http://vantaiquoctuan.vn/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315713741\\0.txt',
#    'D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315713741\\1.txt'],
#   'name': 'CÔNG TY TNHH HÀNG HẢI QUỐC TUẤN',
#   'industry_text': 'Bán buôn máy móc, thiết bị và phụ tùng máy khác'},
#  '315715957': {'urls': ['https://dauthau.asia/businesslistings/detail/CONG-TY-TNHH-THUONG-MAI-KY-THUAT-VA-DICH-VU-THONG-NHAT-33115/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315715957\\0.txt'],
#   'name': 'CÔNG TY TNHH TM DV THỐNG NHẤT',
#   'industry_text': 'Bán buôn chuyên doanh khác chưa được phân vào đâu,Bán buôn kim loại và quặng kim loại,Thu gom rác thải độc hại,Tái chế phế liệu,Thu gom rác thải không độc hại'},
#  '315714914': {'urls': ['http://inminhquan.com/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315714914\\0.txt'],
#   'name': 'CÔNG TY TNHH IN ẤN LÊ MINH QUÂN',
#   'industry_text': 'In ấn,Dịch vụ liên quan đến in,Sao chép bản ghi các loại'},
#  '315714600': {'urls': ['https://annhienfood.com.vn/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315714600\\0.txt'],
#   'name': 'CÔNG TY TNHH SẢN XUẤT THƯƠNG MẠI DỊCH VỤ DINH DƯỠNG PHÁT AN NHIÊN',
#   'industry_text': 'Bán buôn thực phẩm,Bán buôn vải, hàng may sẵn, giày dép,Bán buôn đồ dùng khác cho gia đình,Bán buôn chuyên doanh khác chưa được phân vào đâu,Dịch vụ đóng gói,Bán lẻ thực phẩm trong các cửa hàng chuyên doanh,Chế biến, bảo quản thịt và các sản phẩm từ thịt,Chế biến, bảo quản thuỷ sản và các sản phẩm từ thuỷ sản,Chế biến và bảo quản rau quả,Sản xuất dầu, mỡ động, thực vật,Sản xuất thực phẩm khác chưa được phân vào đâu,Sản xuất đồ uống không cồn, nước khoáng'},
#  '315711381': {'urls': ['https://cokhitudongchiho.com/lien-he'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315711381\\0.txt'],
#   'name': 'CÔNG TY TNHH CƠ KHÍ HƯỚNG PHONG',
#   'industry_text': 'Sửa chữa thiết bị khác,Dịch vụ hệ thống bảo đảm an toàn,Sửa chữa máy móc, thiết bị,Bán lẻ đồ điện gia dụng, giường, tủ, bàn, ghế và đồ nội thất tương tự, đèn và bộ đèn điện, đồ dùng gia đình khác chưa được phân vào đâu trong các cửa hàng chuyên doanh,Lắp đặt máy móc và thiết bị công nghiệp,Bán buôn máy móc, thiết bị và phụ tùng máy khác,Lắp đặt hệ thống điện,Bán buôn chuyên doanh khác chưa được phân vào đâu,Sửa chữa thiết bị điện,Hoạt động kiến trúc và tư vấn kỹ thuật có liên quan,Gia công cơ khí; xử lý và tráng phủ kim loại,Sửa chữa thiết bị điện tử và quang học'},
#  '315715587': {'urls': ['https://denledchatluongcao.vn/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315715587\\0.txt'],
#   'name': 'CÔNG TY CỔ PHẦN GIẢI PHÁP CHIẾU SÁNG VÀ NĂNG LƯỢNG SOHOBI',
#   'industry_text': 'Bán buôn chuyên doanh khác chưa được phân vào đâu,Sửa chữa máy móc, thiết bị,Lắp đặt máy móc và thiết bị công nghiệp,Bán buôn máy móc, thiết bị và phụ tùng máy khác,Lắp đặt hệ thống điện,Bán buôn thiết bị và linh kiện điện tử, viễn thông,Bán buôn đồ dùng khác cho gia đình,Bán buôn máy vi tính, thiết bị ngoại vi và phần mềm'},
#  '315715442': {'urls': ['https://automation-tienquan.com/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315715442\\0.txt'],
#   'name': 'CÔNG TY TNHH MT TIẾN QUÂN',
#   'industry_text': 'May trang phục (trừ trang phục từ da lông thú),Sản xuất thảm, chăn, đệm,Sản xuất giày dép,Bán buôn máy móc, thiết bị và phụ tùng máy khác,Sản xuất các loại hàng dệt khác chưa được phân vào đâu,Bán lẻ vải, len, sợi, chỉ khâu và hàng dệt khác trong các cửa hàng chuyên doanh,Sản xuất vải dệt kim, vải đan móc và vải không dệt khác,Sản xuất hàng dệt sẵn (trừ trang phục),Bán lẻ hàng may mặc, giày dép, hàng da và giả da trong các cửa hàng chuyên doanh,Bán lẻ hàng hóa khác mới trong các cửa hàng chuyên doanh,Bán buôn vải, hàng may sẵn, giày dép,Bán buôn chuyên doanh khác chưa được phân vào đâu,Sản xuất các loại dây bện và lưới,Sản xuất sản phẩm từ da lông thú,Bán lẻ sách, báo, tạp chí văn phòng phẩm trong các cửa hàng chuyên doanh,Bán buôn đồ dùng khác cho gia đình,Hoạt động dịch vụ hỗ trợ kinh doanh khác còn lại chưa được phân vào đâu,Sản xuất trang phục dệt kim, đan móc,Dịch vụ đóng gói,Hoàn thiện sản phẩm dệt,Thuộc, sơ chế da; sơ chế và nhuộm da lông thú,Sản xuất sợi,Sản xuất vải dệt thoi,Sản xuất vali, túi xách và các loại tương tự, sản xuất yên đệm'},
#  '315714745': {'urls': ['https://daihoabinhduong.com/',
#    'https://daihoaco.com/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315714745\\0.txt',
#    'D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315714745\\1.txt'],
#   'name': 'CÔNG TY TNHH ĐẠI HOÀ JA',
#   'industry_text': 'Giáo dục khác chưa được phân vào đâu,Hoạt động thư viện và lưu trữ,Tổ chức giới thiệu và xúc tiến thương mại,Dịch vụ liên quan đến in,Hoạt động chuyên môn, khoa học và công nghệ khác chưa được phân vào đâu,In ấn,Dịch vụ hỗ trợ giáo dục,Quảng cáo'},
#  '315714590': {'urls': ['https://globalfoodsource.vn/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315714590\\1.txt'],
#   'name': 'CÔNG TY TNHH NỮ HOÀNG MÙA XUÂN',
#   'industry_text': 'Bán buôn đồ dùng khác cho gia đình,Bán lẻ thuốc, dụng cụ y tế, mỹ phẩm và vật phẩm vệ sinh trong các cửa hàng chuyên doanh,Bán lẻ hàng hóa khác mới trong các cửa hàng chuyên doanh,Hoạt động dịch vụ hỗ trợ kinh doanh khác còn lại chưa được phân vào đâu,Bán lẻ khác trong các cửa hàng kinh doanh tổng hợp,Bán lẻ hàng hóa khác lưu động hoặc tại chợ'},
#  '315714720': {'urls': ['https://huunghiplastic.com.vn/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315714720\\0.txt'],
#   'name': 'CÔNG TY TNHH HẠT NHỰA HỮU NGHỊ',
#   'industry_text': 'Sản xuất sản phẩm từ plastic,Tái chế phế liệu,Bán buôn chuyên doanh khác chưa được phân vào đâu'},
#  '315707931': {'urls': ['https://ematechvn.com/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315707931\\0.txt'],
#   'name': 'CÔNG TY TNHH EMA TECH',
#   'industry_text': 'Sản xuất thực phẩm khác chưa được phân vào đâu,Sản xuất hàng dệt sẵn (trừ trang phục),Gia công cơ khí; xử lý và tráng phủ kim loại,Sản xuất các thiết bị nâng, hạ và bốc xếp,Sửa chữa máy móc, thiết bị,Sửa chữa và bảo dưỡng phương tiện vận tải (trừ ô tô, mô tô, xe máy và xe có động cơ khác),Lắp đặt máy móc và thiết bị công nghiệp,Thoát nước và xử lý nước thải,Xử lý và tiêu huỷ rác thải không độc hại,Xử lý ô nhiễm và hoạt động quản lý chất thải khác,Xây dựng nhà để ở,Xây dựng nhà không để ở,Lắp đặt hệ thống điện,Lắp đặt hệ thống cấp, thoát nước, lò sưởi và điều hoà không khí,Lắp đặt hệ thống xây dựng khác,Bán buôn ô tô và xe có động cơ khác,Bảo dưỡng, sửa chữa ô tô và xe có động cơ khác,Đại lý, môi giới, đấu giá,Bán buôn thực phẩm,Bán buôn đồ dùng khác cho gia đình,Bán buôn thiết bị và linh kiện điện tử, viễn thông,Bán buôn máy móc, thiết bị và phụ tùng máy khác,Bán buôn vật liệu, thiết bị lắp đặt khác trong xây dựng,Bán buôn chuyên doanh khác chưa được phân vào đâu,Cho thuê máy móc, thiết bị và đồ dùng hữu hình khác'},
#  '315703013': {'urls': ['https://baocaothongtin.com/vi/congty/vn-VN0001430704/hung-uy-vuong-production-trading-service-company-limited/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315703013\\0.txt'],
#   'name': 'CÔNG TY TNHH SẢN XUẤT THƯƠNG MẠI DỊCH VỤ HÙNG UY VƯƠNG',
#   'industry_text': 'Gia công cơ khí; xử lý và tráng phủ kim loại,Bán buôn chuyên doanh khác chưa được phân vào đâu'},
#  '315714921': {'urls': ['https://infodoanhnghiep.com/thong-tin/Cty-TNHH-MTV-Thuong-Mai-Dich-Vu-Hoa-Bi-49927.html'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315714921\\0.txt'],
#   'name': 'CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ HỌA BÌ',
#   'industry_text': 'Hoạt động dịch vụ phục vụ cá nhân khác còn lại chưa được phân vào đâu'},
#  '315715731': {'urls': ['https://www.yenviet.com.vn/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315715731\\0.txt'],
#   'name': 'CÔNG TY TNHH ĐẠI YẾN VIỆT',
#   'industry_text': 'Nhà hàng và các dịch vụ ăn uống phục vụ lưu động,Dịch vụ ăn uống khác,Bán lẻ đồ điện gia dụng, giường, tủ, bàn, ghế và đồ nội thất tương tự, đèn và bộ đèn điện, đồ dùng gia đình khác chưa được phân vào đâu trong các cửa hàng chuyên doanh,Bán buôn vật liệu, thiết bị lắp đặt khác trong xây dựng,Dịch vụ phục vụ đồ uống,Dịch vụ lưu trú ngắn ngày,Bán buôn thiết bị và linh kiện điện tử, viễn thông,Hoạt động chuyên môn, khoa học và công nghệ khác chưa được phân vào đâu,Bán buôn đồ dùng khác cho gia đình,Bán buôn máy vi tính, thiết bị ngoại vi và phần mềm'},
#  '315713572': {'urls': ['http://euroland.dichvuvietbaichuanseo.com/'],
#   'paths': ['D:\\PUBLIC_DATA_PROJECT\\Check_main_url\\crawl\\company_information\\315713572\\0.txt'],
#   'name': 'CÔNG TY TNHH ĐẦU TƯ VÀ PHÁT TRIỂN EURO LAND VIỆT NAM',
#   'industry_text': 'Tư vấn, môi giới, đấu giá bất động sản, đấu giá quyền sử dụng đất'}}

# %% [markdown]
# # MODEL

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from transformers import AutoTokenizer, AutoModel
import torch
from underthesea import word_tokenize


class SimilarityCalculator:
    def __init__(self):
        # Load models
        self.sbert_model = SentenceTransformer('distiluse-base-multilingual-cased-v1')
        self.labse_model = SentenceTransformer('sentence-transformers/LaBSE')
        self.tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base")
        # self.phobert_model = AutoModel.from_pretrained("vinai/phobert-base")
        self.vectorizer = TfidfVectorizer(stop_words='english')  # Can be customized for Vietnamese stop words

    def preprocess_text(self, text):
        # Tokenize Vietnamese text
        return ' '.join(word_tokenize(text))

    def get_embedding_sbert(self, text):
        return self.sbert_model.encode(text)

    def get_embedding_labse(self, text):
        return self.labse_model.encode(text)

    def get_embedding_phobert(self, text):
        inputs = self.tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=2000)
        with torch.no_grad():
            outputs = self.phobert_model(**inputs)
            cls_embedding = outputs.last_hidden_state[:, 0, :].squeeze().numpy()
        return cls_embedding

    def get_similarity(self, urls, industry_text, website_texts, model_name='all'):
        # Preprocess the text
        industry_text = self.preprocess_text(industry_text)
        website_texts = [self.preprocess_text(text) for text in website_texts]

        # Initialize DataFrame to store results
        results = pd.DataFrame({'url': [urls[i] for i in range(len(website_texts))]})

        if model_name in ['all', 'sbert']:
            industry_embedding_sbert = self.get_embedding_sbert(industry_text)
            website_embeddings_sbert = [self.get_embedding_sbert(text) for text in website_texts]
            similarities_sbert = cosine_similarity([industry_embedding_sbert], website_embeddings_sbert)[0]
            results['SBERT Similarity'] = similarities_sbert

        if model_name in ['all', 'labse']:
            industry_embedding_labse = self.get_embedding_labse(industry_text)
            website_embeddings_labse = [self.get_embedding_labse(text) for text in website_texts]
            similarities_labse = cosine_similarity([industry_embedding_labse], website_embeddings_labse)[0]
            results['LaBSE Similarity'] = similarities_labse

        if model_name in ['all', 'tfidf']:
            all_texts = [industry_text] + website_texts
            tfidf_matrix = self.vectorizer.fit_transform(all_texts)
            industry_vector_tfidf = tfidf_matrix[0]
            website_vectors_tfidf = tfidf_matrix[1:]
            similarities_tfidf = cosine_similarity(industry_vector_tfidf, website_vectors_tfidf)[0]
            results['TF-IDF Similarity'] = similarities_tfidf

        # if model_name in ['all', 'phobert']:
        #     industry_embedding_phobert = self.get_embedding_phobert(industry_text)
        #     website_embeddings_phobert = [self.get_embedding_phobert(text) for text in website_texts]
        #     similarities_phobert = cosine_similarity([industry_embedding_phobert], website_embeddings_phobert)[0]
        #     results['PhoBERT Similarity'] = similarities_phobert
        
        return results

# %%
# Example usage
industry_text = "Nganh, nghe )( buon ban du lieu"
website_texts = [
    "Chung toi buon ban )( du lieu va cong nghe",
    "Ben cung cap cong nghe",
    "Hien tai chung toi dang phat trien he thong",
]
websites = ["web1", "web2", "web3"]
# Initialize the calculator
similarity_calculator = SimilarityCalculator()

# Get similarities with all models
results = similarity_calculator.get_similarity(websites,industry_text, website_texts, model_name='all')
print(results)
# Out:
#     url  SBERT Similarity  LaBSE Similarity  TF-IDF Similarity
# 0  web1          0.753583          0.782316           0.611115
# 1  web2          0.310079          0.443528           0.102860
# 2  web3          0.308614          0.255703           0.000000

# %%
df
# Out:
#                                          link_company  \
# 0   https://hosocongty.vn/tap-doan-vingroup-cong-t...
# 1   https://hosocongty.vn/tong-cong-ty-bao-hiem-ba...
# 2   https://hosocongty.vn/cong-ty-co-phan-bibica-c...
# 3   https://hosocongty.vn/cong-ty-co-phan-bao-hiem...
# 4   https://hosocongty.vn/cong-ty-co-phan-nhua-va-...
# 5   https://hosocongty.vn/cong-ty-tnhh-p-p-healing...
# 6   https://hosocongty.vn/cong-ty-tnhh-xuat-nhap-k...
# 7   https://hosocongty.vn/cong-ty-tnhh-dich-vu-bat...
# 8   https://hosocongty.vn/cong-ty-tnhh-thuong-mai-...
# 9   https://hosocongty.vn/cong-ty-tnhh-thuong-mai-...
# 10  https://hosocongty.vn/cong-ty-tnhh-my-pham-spa...
# 11  https://hosocongty.vn/cong-ty-co-phan-viet-fas...
# 12  https://hosocongty.vn/cong-ty-co-phan-tinh-hoa...
# 13                    CÔNG TY CỔ PHẦN MỸ PHẨM MIOSKIN   315717979.0
# 14                    CÔNG TY TNHH DỊCH VỤ SHANGRI-LA   315715883.0
# 15                    CÔNG TY TNHH HÀNG HẢI QUỐC TUẤN   315713741.0
# 16        CÔNG TY TNHH ĐẦU TƯ PHÁT TRIỂN K&N VIỆT NAM   315712956.0
# 17  CÔNG TY TNHH TƯ VẤN ĐẦU TƯ BẤT ĐỘNG SẢN HẢI NG...   315704306.0
# 18                      CÔNG TY TNHH TM DV THỐNG NHẤT   315715957.0
# 19                    CÔNG TY TNHH IN ẤN LÊ MINH QUÂN   315714914.0
# 20  CÔNG TY TNHH SẢN XUẤT THƯƠNG MẠI DỊCH VỤ DINH ...   315714600.0
# 21                    CÔNG TY TNHH CƠ KHÍ HƯỚNG PHONG   315711381.0
# 22  CÔNG TY CỔ PHẦN GIẢI PHÁP CHIẾU SÁNG VÀ NĂNG L...   315715587.0
# 23                               CÔNG TY TNHH SENTMEN   315715717.0
# 24                          CÔNG TY TNHH MT TIẾN QUÂN   315715442.0
# 25                            CÔNG TY TNHH ĐẠI HOÀ JA   315714745.0
# 26                     CÔNG TY TNHH NỮ HOÀNG MÙA XUÂN   315714590.0
# 27                  CÔNG TY TNHH TOP QUALITY FOR HOME   315709505.0
# 28                     CÔNG TY TNHH HẠT NHỰA HỮU NGHỊ   315714720.0
# 29         CÔNG TY TNHH THƯƠNG MẠI HONG PU TRUNG QUỐC   315716100.0
# 30                  CÔNG TY TNHH GLOBAL STONE IMP&EXP   315716037.0
# 31                              CÔNG TY TNHH EMA TECH   315707931.0
# 32  CÔNG TY TNHH SẢN XUẤT THƯƠNG MẠI DỊCH VỤ HÙNG ...   315703013.0
# 33  CÔNG TY TNHH KINH DOANH THƯƠNG MẠI DỊCH VỤ HOÀ...   315715971.0
# 34             CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ HỌA BÌ   315714921.0
# 35                          CÔNG TY TNHH ĐẠI YẾN VIỆT   315715731.0
# 36                    CÔNG TY TNHH ZHONGHENG PRINTING   315714752.0
# 37  CÔNG TY TNHH ĐẦU TƯ VÀ PHÁT TRIỂN EURO LAND VI...   315713572.0
# 38         CÔNG TY TNHH BẤT ĐỘNG SẢN HOÀNG THIÊN PHÁT   315712360.0
#
#                            status_of_company  \
# 0       Đang hoạt động (đã được cấp GCN ĐKT)
# 1                                        NaN
# 2       Đang hoạt động (đã được cấp GCN ĐKT)
# 3                                        NaN
# 4                                        NaN
# 5   NNT đang hoạt động (đã được cấp GCN ĐKT)
# 6   NNT đang hoạt động (đã được cấp GCN ĐKT)
# 7   NNT đang hoạt động (đã được cấp GCN ĐKT)
# 8   NNT đang hoạt động (đã được cấp GCN ĐKT)
# 9   NNT đang hoạt động (đã được cấp GCN ĐKT)
# 10  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 11  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 12  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 13      Đang hoạt động (đã được cấp GCN ĐKT)
# 14  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 15  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 16  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 17  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 18  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 19  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 20  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 21  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 22  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 23  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 24  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 25  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 26  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 27  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 28  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 29  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 30  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 31  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 32  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 33  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 34  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 35  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 36  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 37  NNT đang hoạt động (đã được cấp GCN ĐKT)
# 38  NNT đang hoạt động (đã được cấp GCN ĐKT)
#
#                                         list_business  \
# 0   [{'5510': 'Dịch vụ lưu trú ngắn ngày'}, {'4772...
# 1           [{'65129': 'Bảo hiểm phi nhân thọ khác'}]
# 2   [{'1071': 'Sản xuất các loại bánh từ bột'}, {'...
# 3   [{'64': 'Hoạt động dịch vụ tài chính (trừ bảo ...
# 4   [{'963': 'Hoạt động dịch vụ phục vụ cá nhân kh...
# 5   [{'4632': 'Bán buôn thực phẩm'}, {'4722': 'Bán...
# 6   [{'4669': 'Bán buôn chuyên doanh khác chưa đượ...
# 7   [{'6820': 'Tư vấn, môi giới, đấu giá bất động ...
# 8   [{'4662': 'Bán buôn kim loại và quặng kim loại...
# 9   [{'4933': 'Vận tải hàng hóa bằng đường bộ'}, {...
# 10  [{'9639': 'Hoạt động dịch vụ phục vụ cá nhân k...
# 11  [{'6810': 'Kinh doanh bất động sản, quyền sử d...
# 12  [{'7020': 'Hoạt động tư vấn quản lý'}, {'8110'...
# 13  [{'4649': 'Bán buôn đồ dùng khác cho gia đình'...
# 14  [{'9610': 'Dịch vụ tắm hơi, massage và các dịc...
# 15  [{'4659': 'Bán buôn máy móc, thiết bị và phụ t...
# 16  [{'9311': 'Hoạt động của các cơ sở thể thao'},...
# 17  [{'6820': 'Tư vấn, môi giới, đấu giá bất động ...
# 18  [{'4669': 'Bán buôn chuyên doanh khác chưa đượ...
# 19  [{'1811': 'In ấn'}, {'1812': 'Dịch vụ liên qua...
# 20  [{'4632': 'Bán buôn thực phẩm'}, {'4641': 'Bán...
# 21  [{'3319': 'Sửa chữa thiết bị khác'}, {'8020': ...
# 22  [{'4669': 'Bán buôn chuyên doanh khác chưa đượ...
# 23  [{'4649': 'Bán buôn đồ dùng khác cho gia đình'...
# 24  [{'1410': 'May trang phục (trừ trang phục từ d...
# 25  [{'8559': 'Giáo dục khác chưa được phân vào đâ...
# 26  [{'4649': 'Bán buôn đồ dùng khác cho gia đình'...
# 27  [{'6820': 'Tư vấn, môi giới, đấu giá bất động ...
# 28  [{'2220': 'Sản xuất sản phẩm từ plastic'}, {'3...
# 29  [{'4659': 'Bán buôn máy móc, thiết bị và phụ t...
# 30  [{'2396': 'Cắt tạo dáng và hoàn thiện đá'}, {'...
# 31  [{'1079': 'Sản xuất thực phẩm khác chưa được p...
# 32  [{'2592': 'Gia công cơ khí; xử lý và tráng phủ...
# 33  [{'4663': 'Bán buôn vật liệu, thiết bị lắp đặt...
# 34  [{'9639': 'Hoạt động dịch vụ phục vụ cá nhân k...
# 35  [{'5610': 'Nhà hàng và các dịch vụ ăn uống phụ...
# 36  [{'1702': 'Sản xuất giấy nhăn, bìa nhăn, bao b...
# 37  [{'6820': 'Tư vấn, môi giới, đấu giá bất động ...
# 38  [{'6820': 'Tư vấn, môi giới, đấu giá bất động ...
#
#                                          list_website  Status  \
# 0   [{'title': 'Trang chủ - Tập đoàn Vingroup', 'u...    True
# 1   [{'title': 'Tổng Công ty Bảo hiểm Bảo Việt', '...    True
# 2   [{'title': 'Bibica - Tinh hoa bánh kẹo Việt', ...    True
# 3   [{'title': 'VNI - Tổng Công Ty Cổ Phần Bảo hiể...    True
# 4   [{'title': 'An Phat Bioplastics', 'url': 'http...    True
# 5   [{'title': 'CÔNG TY TNHH P-TRADING', 'url': 'h...    True
# 6   [{'title': '0315717954 - CÔNG TY TNHH XUẤT NHẬ...    True
# 7   [{'title': 'CÔNG TY TNHH DỊCH VỤ BẤT ĐỘNG SẢN ...    True
# 8   [{'title': 'CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ C....    True
# 9   [{'title': '0315717898 - CÔNG TY TNHH THƯƠNG M...    True
# 10  [{'title': 'CÔNG TY TNHH MỸ PHẨM SPA BEAUTY QU...    True
# 11  [{'title': '0315717993 - CÔNG TY CỔ PHẦN VIET ...    True
# 12  [{'title': '0316923244 - CÔNG TY TNHH TINH HOA...    True
# 13  [{'title': 'Xịt dưỡng tế bào gốc MIOSKIN - nhậ...    True
# 14  [{'title': '0315715883 - CÔNG TY TNHH DỊCH VỤ ...    True
# 15  [{'title': '0315713741 - CÔNG TY TNHH HÀNG HẢI...    True
# 16  [{'title': 'CÔNG TY TNHH ĐẦU TƯ VÀ PHÁT TRIỂN ...    True
# 17  [{'title': 'CÔNG TY TNHH TƯ VẤN ĐẦU TƯ BẤT ĐỘN...    True
# 18  [{'title': '6000931810 - CÔNG TY TNHH MỘT THÀN...    True
# 19  [{'title': '0315714914 - CÔNG TY TNHH IN ẤN LÊ...    True
# 20  [{'title': '0315714600 - CÔNG TY TNHH SẢN XUẤT...    True
# 21  [{'title': '0315711381 - CÔNG TY TNHH CƠ KHÍ H...    True
# 22  [{'title': '0315715587 - CÔNG TY CỔ PHẦN CHIẾU...    True
# 23  [{'title': '0315715717 - CÔNG TY TNHH SENTMEN'...    True
# 24  [{'title': 'CÔNG TY TNHH MT TIẾN QUÂN - Mã số ...    True
# 25  [{'title': '0315714745 - CÔNG TY TNHH ĐẠI HOÀ ...    True
# 26  [{'title': '0315714590 - CÔNG TY TNHH NỮ HOÀNG...    True
# 27  [{'title': '0315709505 - CÔNG TY TNHH TOP QUAL...    True
# 28  [{'title': '0315714720 - CÔNG TY TNHH HẠT NHỰA...    True
# 29  [{'title': 'Công Ty TNHH Thương Mại Pu Hong Tr...    True
# 30  [{'title': 'CÔNG TY TNHH MTV XUẤT NHẬP KHẨU GL...    True
# 31  [{'title': 'CÔNG TY TNHH EMA TECH: Homepage', ...    True
# 32  [{'title': '0315703013 - CÔNG TY TNHH SẢN XUẤT...    True
# 33  [{'title': 'CÔNG TY TNHH KINH DOANH THƯƠNG MẠI...    True
# 34  [{'title': 'CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ HỌ...    True
# 35  [{'title': '0315715731 - CÔNG TY TNHH ĐẠI YẾN ...    True
# 36  [{'title': '0315714752-001 - CHI NHÁNH BÌNH DƯ...    True
# 37  [{'title': 'Euroland.vn: Trang chủ', 'url': 'h...    True
# 38  [{'title': 'CÔNG TY TNHH BẤT ĐỘNG SẢN HOÀNG TH...    True
#
#                                    international_name  acronyms_name  \
# 0                                                 NaN            NaN
# 1                                                 NaN            NaN
# 2                                                 NaN            NaN
# 3                                                 NaN            NaN
# 4                                                 NaN            NaN
# 5                           P&P HEALING HOUSE CO.,LTD            NaN
# 6                         KORE IMPORT EXPORT CO., LTD            NaN
# 7           H & N REAL ESTATE SERVICE COMPANY LIMITED            NaN
# 8                                                 NaN            NaN
# 9                                                 NaN            NaN
# 10                                                NaN            NaN
# 11                                 VIET FAST HOLDINGS            NaN
# 12     TINH HOA BACH NGHE SMENTOR JOINT STOCK COMPANY            NaN
# 13                               MIOSKIN COSMETIC JSC            NaN
# 14                                                NaN            NaN
# 15                          QUOC TUAN MARINE CO., LTD            NaN
# 16  K&N VIET NAM DEVELOPMENTAL INVESTMENT COMPANY ...            NaN
# 17                             HAI NGUYEN REAL ESTATE            NaN
# 18                  THE UNIFIED DV TM COMPANY LIMITED            NaN
# 19              LE MINH QUAN PRINTING COMPANY LIMITED            NaN
# 20  PHAT AN NHIEN NUTRITION SERVICE TRADING PRODUC...            NaN
# 21                             HUONG PHONG MECHANICAL            NaN
# 22                SOHOBI LIGHTING AND ENERGY SOLUTION            NaN
# 23                                   SENTMEN CO., LTD            NaN
# 24                                       MT TIEN QUAN            NaN
# 25                         DAI HOA JA COMPANY LIMITED            NaN
# 26                                       QUEEN SPRING            NaN
# 27                                        CÔNG TY TQH            NaN
# 28                                                NaN            NaN
# 29    HANG THINH SERVICE TRADINGINTERNATIONAL CO.,LTD            NaN
# 30                                                NaN            NaN
# 27  Số 237/42/12 Hoàng Diệu, phường 08, Quận 4, TP...   HUỲNH THỊ THANH TRÚC
# 28  B7/6D, ấp 2, Xã Vĩnh Lộc A, Huyện Bình Chánh, ...      LÊ ĐỖ NGUYÊN HẠNH
# 29  Số 15 Đường 40B, Khu Phố 8, Phường Tân Tạo, Qu...           CẦM THỊ PHẠM
# 30  369/6 Đinh Bộ Lĩnh, Phường 26, Quận Bình Thạnh...           HUANG WEILIN
# 31  76/44 Đường số 59, Phường 14, Quận Gò Vấp, Thà...          LÊ HOÀNG NHÂN
# 32     166 Vĩnh Viễn, Phường 09, Quận 10, Hồ Chí Minh      TRẦN NGỌC PHI YẾN
# 33  118/86 Phan Huy ích, Phường 15, Quận Tân Bình,...       NGUYỄN THỊ HƯỜNG
# 34  23/6 Hoàng Văn Thụ, Phường 15, Quận Phú Nhuận,...      NGUYỄN NGỌC THẮNG
# 35   66B Cao Thắng, Phường 04, Quận 3, TP Hồ Chí Minh             VŨ THỊ YẾN
# 36  186 Tên Lửa, Phường Bình Trị Đông B, Quận Bình...          LÊ THIỆN TIẾN
# 37  107-111 Nguyễn Đình Chiểu, Phường 06, Quận 3, ...          PHẠM VIỆT ANH
# 38  T2 208/4 Đường 138, Tổ 3, Khu Phố 4, Phường Tâ...           PHẠM TIẾN SỰ
#
#      phone_number day_of_operation  \
# 0             NaN              NaN
# 1             NaN              NaN
# 2             NaN              NaN
# 3             NaN              NaN
# 4             NaN              NaN
# 5       387007081       04/06/2019
# 6             NaN       04/06/2019
# 7             NaN       04/06/2019
# 8       985377788       04/06/2019
# 9       901447338       04/06/2019
# 10            NaN       04/06/2019
# 11  (028)22676999       04/06/2019
# 12            NaN       04/06/2019
# 13      938961194       04/06/2019
# 14            NaN       04/06/2019
# 15      983189089       04/06/2019
# 16            NaN       04/06/2019
# 17            NaN       04/06/2019
# 18      901229387       04/06/2019
# 19            NaN       04/06/2019
# 20            NaN       04/06/2019
# 21      768603686       04/06/2019
# 22            NaN       04/06/2019
# 23            NaN       04/06/2019
# 24            NaN       04/06/2019
# 25            NaN       04/06/2019
# 26            NaN       04/06/2019
# 27      888661898       04/06/2019
# 28      909958211       04/06/2019
# 29      787950564       04/06/2019
# 30      967362323       04/06/2019
# 31            NaN       04/06/2019
# 32            NaN       04/06/2019
# 33            NaN       04/06/2019
# 34      933456792       04/06/2019
# 35      985848382       04/06/2019
# 36      989211889       04/06/2019
# 37            NaN       04/06/2019
# 38            NaN       04/06/2019
#
#                                              main_job      update_time  \
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3                                                 NaN              NaN
# 4                                                 NaN              NaN
# 5                                  Bán buôn thực phẩm         4/6/2019
# 6    Bán buôn chuyên doanh khác chưa được phân vào...         4/6/2019
# 7    Tư vấn, môi giới, đấu giá bất động sản, đấu g...         4/6/2019
# 8                 Bán buôn kim loại và quặng kim loại         4/6/2019
# 9                      Vận tải hàng hóa bằng đường bộ         4/6/2019
# 10   Hoạt động dịch vụ phục vụ cá nhân khác còn lạ...         4/6/2019
# 17  315704306.0                                                 []
# 18  315715957.0  [https://dauthau.asia/businesslistings/detail/...
# 19  315714914.0                           [http://inminhquan.com/]
# 20  315714600.0                      [https://annhienfood.com.vn/]
# 21  315711381.0             [https://cokhitudongchiho.com/lien-he]
# 22  315715587.0                   [https://denledchatluongcao.vn/]
# 23  315715717.0                                                 []
# 24  315715442.0                 [https://automation-tienquan.com/]
# 25  315714745.0  [https://daihoabinhduong.com/, https://daihoac...
# 26  315714590.0  [https://nuhoanghodiep.com/, https://globalfoo...
# 27  315709505.0                                                 []
# 28  315714720.0                   [https://huunghiplastic.com.vn/]
# 29  315716100.0                                                 []
# 30  315716037.0                                                 []
# 31  315707931.0                           [https://ematechvn.com/]
# 32  315703013.0  [https://baocaothongtin.com/vi/congty/vn-VN000...
# 33  315715971.0                                                 []
# 34  315714921.0  [https://infodoanhnghiep.com/thong-tin/Cty-TNH...
# 35  315715731.0                      [https://www.yenviet.com.vn/]
# 36  315714752.0                                                 []
# 37  315713572.0       [http://euroland.dichvuvietbaichuanseo.com/]
# 38  315712360.0                                                 []

# %%
import os

def load_text_from_paths(paths):
    # Initialize an empty list to store website texts
    website_texts = []
    
    # Read each file's content
    for path in paths:
        with open(path, 'r', encoding='utf-8') as file:
            content = file.read().strip()  # Remove any extra whitespace
            website_texts.append(content)
    
    return website_texts

data = business_meta["101245486"]
# Load texts from paths
website_texts = load_text_from_paths(data['paths'])

# Print output
industry_text = data['industry_text']
print("Industry text:", industry_text)
print("Website texts:", website_texts)
# Out:
# Industry text: Dịch vụ lưu trú ngắn ngày,Bán lẻ thuốc, dụng cụ y tế, mỹ phẩm và vật phẩm vệ sinh trong các cửa hàng chuyên doanh,Nhà hàng và các dịch vụ ăn uống phục vụ lưu động,Tư vấn máy vi tính và quản trị hệ thống máy vi tính,Hoạt động dịch vụ công nghệ thông tin và dịch vụ khác liên quan đến máy vi tính,Xử lý dữ liệu, cho thuê và các hoạt động liên quan,Khai thác, xử lý và cung cấp nước,Thoát nước và xử lý nước thải,Thu gom rác thải không độc hại,Phá dỡ,Chuẩn bị mặt bằng,Lắp đặt hệ thống điện,Lắp đặt hệ thống xây dựng khác,Hoàn thiện công trình xây dựng,Hoạt động xây dựng chuyên dụng khác,Bán buôn nông, lâm sản nguyên liệu (trừ gỗ, tre, nứa) và động vật sống,Bán buôn đồ dùng khác cho gia đình,Bán buôn máy móc, thiết bị và phụ tùng máy khác,Hoạt động sáng tác, nghệ thuật và giải trí,Hoạt động của các cơ sở thể thao,Hoạt động của các công viên vui chơi và công viên theo chủ đề,Hoạt động vui chơi giải trí khác chưa được phân vào đâu,Hoạt động hỗ trợ dịch vụ tài chính chưa được phân vào đâu,Kinh doanh bất động sản, quyền sử dụng đất thuộc chủ sở hữu, chủ sử dụng hoặc đi thuê,Tư vấn, môi giới, đấu giá bất động sản, đấu giá quyền sử dụng đất,Hoạt động của trụ sở văn phòng,Hoạt động tư vấn quản lý,Hoạt động kiến trúc và tư vấn kỹ thuật có liên quan,Quảng cá
#  'industry_text': 'Dịch vụ lưu trú ngắn ngày,Bán lẻ thuốc, dụng cụ y tế, mỹ phẩm và vật phẩm vệ sinh trong các cửa hàng chuyên doanh,Nhà hàng và các dịch vụ ăn uống phục vụ lưu động,Tư vấn máy vi tính và quản trị hệ thống máy vi tính,Hoạt động dịch vụ công nghệ thông tin và dịch vụ khác liên quan đến máy vi tính,Xử lý dữ liệu, cho thuê và các hoạt động liên quan,Khai thác, xử lý và cung cấp nước,Thoát nước và xử lý nước thải,Thu gom rác thải không độc hại,Phá dỡ,Chuẩn bị mặt bằng,Lắp đặt hệ thống điện,Lắp đặt hệ thống xây dựng khác,Hoàn thiện công trình xây dựng,Hoạt động xây dựng chuyên dụng khác,Bán buôn nông, lâm sản nguyên liệu (trừ gỗ, tre, nứa) và động vật sống,Bán buôn đồ dùng khác cho gia đình,Bán buôn máy móc, thiết bị và phụ tùng máy khác,Hoạt động sáng tác, nghệ thuật và giải trí,Hoạt động của các cơ sở thể thao,Hoạt động của các công viên vui chơi và công viên theo chủ đề,Hoạt động vui chơi giải trí khác chưa được phân vào đâu,Hoạt động hỗ trợ dịch vụ tài chính chưa được phân vào đâu,Kinh doanh bất động sản, quyền sử dụng đất thuộc chủ sở hữu, chủ sử dụng hoặc đi thuê,Tư vấn, môi giới, đấu giá bất động sản, đấu giá quyền sử dụng đất,Hoạt động của trụ sở văn phòng,Hoạt động tư vấn quản lý,Hoạt động kiến trúc và tư vấn kỹ thuật có liên quan,Quảng cáo,Nghiên cứu thị trường và thăm dò dư luận,Dịch vụ hành chính văn phòng tổng hợp,Lắp đặt hệ thống cấp, thoát nước, lò sưởi và điều hoà không khí,Đại lý, môi giới, đấu giá,Xây dựng nhà để ở,Xây dựng nhà không để ở,Xây dựng công trình đường sắt,Xây dựng công trình đường bộ,Xây dựng công trình công ích khác,Xây dựng công trình kỹ thuật dân dụng khác'}

# %%
# Initialize the calculator
similarity_calculator = SimilarityCalculator()

# Get similarities with all models
results = similarity_calculator.get_similarity(data['urls'] ,industry_text, website_texts, model_name='all')
results
# Out:
#                                                  url  SBERT Similarity  \
# 0                              https://vingroup.net/          0.807757
# 1  https://mekongasean.vn/to-ng-ta-i-sa-n-vingrou...          0.845396
#
#    LaBSE Similarity  TF-IDF Similarity
# 0          0.567719           0.289556
# 1          0.537641           0.223925

# %%
list(results['url'])
# Out:
# ['https://vingroup.net/',
#  'https://mekongasean.vn/to-ng-ta-i-sa-n-vingroup-vuot-nguong-700000-ty-do-ng-31407.html#:~:text=T%E1%BB%95ng%20s%E1%BB%91%20n%E1%BB%A3%20c%E1%BB%A7a%20Vingroup,l%E1%BB%9Bn%20v%E1%BB%9Bi%20418.112%20t%E1%BB%B7%20%C4%91%E1%BB%93ng.']

# %%
torch.cuda.empty_cache()

# %%
torch.cuda.memory_summary(device=None, abbreviated=False)
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 0            |        cudaMalloc retries: 0         |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      |   4639 MiB |   4650 MiB |   5846 MiB |   1207 MiB |\n|       from large pool |   4637 MiB |   4643 MiB |   5357 MiB |    720 MiB |\n|       from small pool |      1 MiB |      6 MiB |    489 MiB |    487 MiB |\n|---------------------------------------------------------------------------|\n| Active memory         |   4639 MiB |   4650 MiB |   5846 MiB |   1207 MiB |\n|       from large pool |   4637 MiB |   4643 MiB |   5357 MiB |    720 MiB |\n|       from small pool |      1 MiB |      6 MiB |    489 MiB |    487 MiB |\n|---------------------------------------------------------------------------|\n| Requested memory      |   4636 MiB |   4647 MiB |   5825 MiB |   1189 MiB |\n|       from large pool |   4635 MiB |   4641 MiB |   5337 MiB |    702 MiB |\n|       from small pool |      1 MiB |      6 MiB |    488 MiB |    487 MiB |\n|---------------------------------------------------------------------------|\n| GPU reserved memory   |   4746 MiB |   4774 MiB |   4774 MiB |  28672 KiB |\n|       from large pool |   4744 MiB |   4764 MiB |   4764 MiB |  20480 KiB |\n|       from small pool |      2 MiB |     10 MiB |     10 MiB |   8192 KiB |\n|---------------------------------------------------------------------------|\n| Non-releasable memory | 109368 KiB | 130609 KiB |   3546 MiB |   3439 MiB |\n|       from large pool | 108800 KiB | 126208 KiB |   2972 MiB |   2866 MiB |\n|       from small pool |    568 KiB |   4913 KiB |    574 MiB |    573 MiB |\n|---------------------------------------------------------------------------|\n| Allocations           |     613    |     626    |    3567    |    2954    |\n|       from large pool |     231    |     233    |     483    |     252    |\n|       from small pool |     382    |     394    |    3084    |    2702    |\n|---------------------------------------------------------------------------|\n| Active allocs         |     613    |     626    |    3567    |    2954    |\n|       from large pool |     231    |     233    |     483    |     252    |\n|       from small pool |     382    |     394    |    3084    |    2702    |\n|---------------------------------------------------------------------------|\n| GPU reserved segments |      60    |      65    |      65    |       5    |\n|       from large pool |      59    |      60    |      60    |       1    |\n|       from small pool |       1    |       5    |       5    |       4    |\n|---------------------------------------------------------------------------|\n| Non-releasable allocs |      53    |      60    |    1543    |    1490    |\n|       from large pool |      52    |      53    |     203    |     151    |\n|       from small pool |       1    |       7    |    1340    |    1339    |\n|---------------------------------------------------------------------------|\n| Oversize allocations  |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize GPU segments |       0    |       0    |       0    |       0    |\n|===========================================================================|\n'

# %%
# print(len(taxs_code
# Out:
# 28

# %% [markdown]
# # Inference

# %%
taxs_code = list(business_meta.keys())
similarity_calculator = SimilarityCalculator()

results = pd.DataFrame([])
for tax_code in taxs_code:
    data = business_meta[tax_code]
    # Load texts from paths
    website_texts = load_text_from_paths(data['paths'])

    # Print output
    industry_text = data['industry_text']

    # Get similarities with all models
    for url, text in zip(data["urls"], website_texts):
        print(f"url: {url}")
        result = similarity_calculator.get_similarity([url] ,industry_text, [text], model_name='all')
        torch.cuda.empty_cache()

        result["name"] = [data['name']]*len(result)

        results = pd.concat([results, result], axis=0)

    torch.cuda.empty_cache()
# Out:
# url: https://vingroup.net/
# 39          0.283597           0.095975
# 40          0.466607           0.063332
# 41          0.447203           0.155446
#
#                                                  name
# 0                     TẬP ĐOÀN VINGROUP -  CÔNG TY CP
# 1                     TẬP ĐOÀN VINGROUP -  CÔNG TY CP
# 2                      TỔNG CÔNG TY BẢO HIỂM BẢO VIỆT
# 3                      TỔNG CÔNG TY BẢO HIỂM BẢO VIỆT
# 4                      TỔNG CÔNG TY BẢO HIỂM BẢO VIỆT
# 5                              CÔNG TY CỔ PHẦN BIBICA
# 6                              CÔNG TY CỔ PHẦN BIBICA
# 7                              CÔNG TY CỔ PHẦN BIBICA
# 8                 CÔNG TY CỔ PHẦN BẢO HIỂM HÀNG KHÔNG
# 9                 CÔNG TY CỔ PHẦN BẢO HIỂM HÀNG KHÔNG
# 10                CÔNG TY CỔ PHẦN BẢO HIỂM HÀNG KHÔNG
# 11    CÔNG TY CỔ PHẦN NHỰA VÀ MÔI TRƯỜNG XANH AN PHÁT
# 12    CÔNG TY CỔ PHẦN NHỰA VÀ MÔI TRƯỜNG XANH AN PHÁT
# 13    CÔNG TY CỔ PHẦN NHỰA VÀ MÔI TRƯỜNG XANH AN PHÁT
# 14                     CÔNG TY TNHH P&P HEALING HOUSE
# 15                     CÔNG TY TNHH P&P HEALING HOUSE
# 16                   CÔNG TY TNHH XUẤT NHẬP KHẨU KORE
# 17            CÔNG TY TNHH DỊCH VỤ BẤT ĐỘNG SẢN H & N
# 18              CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ C.Z.C
# 19              CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ C.Z.C
# 20              CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ C.Z.C
# 21  CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ VẬN TẢI SONG NHẬT
# 22              CÔNG TY TNHH MỸ PHẨM SPA BEAUTY QUEEN
# 23                    CÔNG TY CỔ PHẦN MỸ PHẨM MIOSKIN
# 24                    CÔNG TY TNHH DỊCH VỤ SHANGRI-LA
# 25                    CÔNG TY TNHH HÀNG HẢI QUỐC TUẤN
# 26                    CÔNG TY TNHH HÀNG HẢI QUỐC TUẤN
# 27                      CÔNG TY TNHH TM DV THỐNG NHẤT
# 28                    CÔNG TY TNHH IN ẤN LÊ MINH QUÂN
# 29  CÔNG TY TNHH SẢN XUẤT THƯƠNG MẠI DỊCH VỤ DINH ...
# 30                    CÔNG TY TNHH CƠ KHÍ HƯỚNG PHONG
# 31  CÔNG TY CỔ PHẦN GIẢI PHÁP CHIẾU SÁNG VÀ NĂNG L...
# 32                          CÔNG TY TNHH MT TIẾN QUÂN
# 33                            CÔNG TY TNHH ĐẠI HOÀ JA
# 34                            CÔNG TY TNHH ĐẠI HOÀ JA
# 35                     CÔNG TY TNHH NỮ HOÀNG MÙA XUÂN
# 36                     CÔNG TY TNHH HẠT NHỰA HỮU NGHỊ
# 37                              CÔNG TY TNHH EMA TECH
# 38  CÔNG TY TNHH SẢN XUẤT THƯƠNG MẠI DỊCH VỤ HÙNG ...
# 39             CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ HỌA BÌ
# 40                          CÔNG TY TNHH ĐẠI YẾN VIỆT
# 41  CÔNG TY TNHH ĐẦU TƯ VÀ PHÁT TRIỂN EURO LAND VI...

# %%
list(results['url'])
# Out:
# ['https://vingroup.net/',
#  'https://mekongasean.vn/to-ng-ta-i-sa-n-vingroup-vuot-nguong-700000-ty-do-ng-31407.html#:~:text=T%E1%BB%95ng%20s%E1%BB%91%20n%E1%BB%A3%20c%E1%BB%A7a%20Vingroup,l%E1%BB%9Bn%20v%E1%BB%9Bi%20418.112%20t%E1%BB%B7%20%C4%91%E1%BB%93ng.',
#  'https://www.baoviet.com.vn/insurance/',
#  'https://baovietonline.com.vn/',
#  'https://baoviet.com.vn/',
#  'https://www.bibica.com.vn/',
#  'https://s.cafef.vn/hose/BBC-cong-ty-co-phan-bibica.chn',
#  'https://finance.vietstock.vn/bbc/ho-so-doanh-nghiep.htm',
#  'https://bhhk.com.vn/',
#  'https://ebhhk.com.vn/gioi-thieu.html',
#  'https://ibaohiem.vn/gioi-thieu-bao-hiem-hang-khong-vni/',
#  'https://anphatbioplastics.com/',
#  'https://finance.vietstock.vn/AAA-ctcp-nhua-an-phat-xanh.htm',
#  'https://www.fact-link.com.vn/home/anphat-vn',
#  'http://p-techno.com/',
#  'https://www.dussmann.vn/vi/dussmann-service/cong-ty/',
#  'https://oneoneone.vn/organic-farms-korea/',
#  'https://www.pghouse.vn/doanh-nghiep-vang/cong-ty-tnhh-dich-vu-bat-dong-san-premier-viet-nam-10875.html',
#  'https://www.taiphat.vn/',
#  'https://minhkhang.com.vn/',
#  'https://vietincoseco.vn/',
#  'https://songnhat.com.vn/',
#  'https://myphambeautyqueen.net/',
#  'https://mioskin.vn/',
#  'https://giaan115.com/tin-tuc/khu-y-te-ky-thuat-cao-hoa-lam-shangri-la-da-ra-doi-nhu-the-nao',
#  'https://doanhnghiepmoi.vn/thong-tin/CONG-TY-TNHH-HANG-HAI-QUOC-TUAN-13741.html',
#  'http://vantaiquoctuan.vn/',
#  'https://dauthau.asia/businesslistings/detail/CONG-TY-TNHH-THUONG-MAI-KY-THUAT-VA-DICH-VU-THONG-NHAT-33115/',
#  'http://inminhquan.com/',
#  'https://annhienfood.com.vn/',
#  'https://cokhitudongchiho.com/lien-he',
#  'https://denledchatluongcao.vn/',
#  'https://automation-tienquan.com/',
#  'https://daihoabinhduong.com/',
#  'https://daihoaco.com/',
#  'https://globalfoodsource.vn/',
#  'https://huunghiplastic.com.vn/',
#  'https://ematechvn.com/',
#  'https://baocaothongtin.com/vi/congty/vn-VN0001430704/hung-uy-vuong-production-trading-service-company-limited/',
#  'https://infodoanhnghiep.com/thong-tin/Cty-TNHH-MTV-Thuong-Mai-Dich-Vu-Hoa-Bi-49927.html',
#  'https://www.yenviet.com.vn/',
#  'http://euroland.dichvuvietbaichuanseo.com/']

# %%
results.to_csv("results.csv")

# %%
pwd
# Out:
# 'd:\\PUBLIC_DATA_PROJECT\\Check_main_url'
